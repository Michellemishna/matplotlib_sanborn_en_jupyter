# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %% [markdown]
# catplot es el grafico por defecto para categoricos ya que este se puede cambiar y editar para cambiar el estilo de grafico que queremos visualizar usando kind

# %%
sns.countplot(data=tips, x='day', hue='sex')
plt.show()

# %% [markdown]
# sns.stripplot([base de datos], x[que quiero en eje x], y[que quiero en eje y], hue[diferencia los datos por este parametro]). dodge[separa las categorias de hue en columnas separadas]

# %%
sns.stripplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True)
plt.show()

# %%
plt.figure(figsize=(3,3))
sns.stripplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True)
plt.show()

# %% [markdown]
# El gráfico resultante es un swarmplot que muestra la distribución de los datos de total_bill para cada día de la semana, diferenciado por el sexo (sex). Los puntos están distribuidos a lo largo del eje y (total_bill) de manera que no se superponen entre sí gracias al uso de un gráfico de enjambre. La separación por sexo (hue='sex') permite comparar visualmente la distribución de total_bill entre hombres y mujeres para cada día.

# %%
plt.figure(figsize=(6,6))
sns.swarmplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True)
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True)
plt.show()

# %% [markdown]
# De la siguiente manera puedes hacer una combinacion de 2 graficos

# %%
plt.figure(figsize=(6,6))
sns.boxplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True)
sns.swarmplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True, palette='dark:0')
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.violinplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True, palette='pastel')
plt.show()

# %%
plt.figure(figsize=(4,4))
sns.violinplot(data=tips, y='total_bill')
plt.show()

# %% [markdown]
# con col puedo generar un graficos por distintos parametros ademas de los que ya esta usando

# %%
sns.catplot(data=tips, x='day', y='total_bill',hue='sex', dodge=True, col='time')
plt.show()
